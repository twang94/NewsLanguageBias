# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
from time import time
# %matplotlib inline

from gensim.corpora import Dictionary
from gensim.models import TfidfModel, LdaModel
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.utils import tokenize
from gensim.parsing import preprocess_string, remove_stopwords, strip_tags, strip_short, strip_numeric, stem_text, strip_punctuation
from gensim.parsing.preprocessing import STOPWORDS
import spacy
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from sklearn.model_selection import StratifiedShuffleSplit

# %%
df_leans = pd.read_pickle('data/df_leans.pkl')

# %%
corpus = df_leans.content

# %%
len(corpus)
# Out:
# 142570

# %%
y = df_leans.leaning.values

# %%
y.shape
# Out:
# (142570,)

# %% [markdown]
# ### Create a stratified sample of the original dataset corpus - this will make Gensim LDA topic modeling faster

# %%
stratified_sample, _, stratified_out, _ = train_test_split(corpus, y, test_size=.90, stratify=y, random_state=5)

# %%
stratified_sample.index
# Out:
# Int64Index([ 34988,  57737, 107158,  80565, 120456, 116926,  98133, 110952,
#              15640,  80117,
#             ...
#             124330,  77337,  85230,  17552, 123227, 133580, 129550,  71448,
#              38090, 132399],
#            dtype='int64', length=14257)

# %%
stratified_out.shape
# Out:
# (14257,)

# %%
df_sample = df_leans.copy()

# %%
df_sample = df_sample[df_sample.index.isin(stratified_sample.index)]

# %%
df_sample
# Out:
#             id                                              title  \
# 10       17293  Weak Federal Powers Could Limit Trump’s Climat...
# 30       17318  Tips for Your Post-Holiday Clutter Purge - The...
# 32       17321  France Lets Workers Turn Off, Tune Out and Liv...
# 59       17352  In Republicans’ Ethics Office Gambit, a Specta...
# 66       17361  How We Put Together Our 52 Places to Go List -...
# ...        ...                                                ...
# 142514  218016  With new monuments in Nevada, Utah, Obama adds...
# 142515  218017  Memo to Trump: There can be only one president...
# 142544  218052  Rare coast-to-coast cold snap to engulf Lower ...
# 142547  218055  A CIA calendar the CIA gift shop refuses to se...
# 142556  218069  On Russia, Trump is incapable of looking past ...
#
#             publication            author        date    year  month  \
# 10       New York Times     Justin Gillis  2017-01-03  2017.0    1.0
# 30       New York Times  Michelle Higgins  2017-04-11  2017.0    4.0
# 32       New York Times   Alissa J. Rubin  2017-01-03  2017.0    1.0
# 59       New York Times        Carl Hulse  2017-01-05  2017.0    1.0
# 66       New York Times               NaN  2017-01-15  2017.0    1.0
# ...                 ...               ...         ...     ...    ...
# 142514  Washington Post   Juliet Eilperin  2016-12-28  2016.0   12.0
# 142515  Washington Post       Ruth Marcus  2016-12-28  2016.0   12.0
# 142544  Washington Post     Jason Samenow  2016-12-29  2016.0   12.0
# 142547  Washington Post       Ian Shapira  2016-12-29  2016.0   12.0
# 142556  Washington Post       Ruth Marcus  2016-12-30  2016.0   12.0
#
#                                                       url  \
# 10                                                    NaN
# 30                                                    NaN
# 32                                                    NaN
# 59                                                    NaN
# 66                                                    NaN
# ...                                                   ...
# 142514  https://web.archive.org/web/20161229004018/htt...
# 142515  https://web.archive.org/web/20161229004018/htt...
# 142544  https://web.archive.org/web/20161230000842/htt...
# 142547  https://web.archive.org/web/20161230000842/htt...
# 142556  https://web.archive.org/web/20161231004909/htt...
#
#                                                   content      leaning factual
# 10      With Donald J. Trump about to take control of ...  Left-Center    High
# 30      With the year winding down and New Year’s reso...  Left-Center    High
# 32      PARIS  —   If the world does not envy the Fren...  Left-Center    High
# 59      WASHINGTON  —   Majorities in Congress often o...  Left-Center    High
# 66      For the 12th straight year, the Travel section...  Left-Center    High
# ...                                                   ...          ...     ...
# 142514        President Obama on Wednesday created new...  Left-Center    High
# 142515   One of the hallmarks of our democratic system...  Left-Center    High
# 142544       Frigid air will grip an unusually large p...  Left-Center    High
# 142547     Far Side cartoons, Ansel Adams landscapes, ...  Left-Center    High
# 142556         Donald Trump, having dismissed as “ridi...  Left-Center    High
#
# [14257 rows x 11 columns]

# %%
def token_preprocess_newstops(string):
    tokens = list(tokenize(string, lower=True, deacc=True))
    tokens = [word for word in tokens if word not in STOPWORDS_U]
    temp_process = ' '.join(tokens)
    tokens = preprocess_string(temp_process, [lambda x: x.lower(), strip_tags, strip_short, strip_numeric, strip_punctuation, stem_text])
    return tokens

# %%
t0 = time()

cleaned_newstop = []
for article in df_sample.content:
    cleaned_newstop.append(token_preprocess_newstops(article))
    
print(time() - t0)
# Out:
# 44.49448251724243

# %%
dictionary_new = corpora.Dictionary(cleaned_newstop)
gen_corpus_new = [dictionary_new.doc2bow(text) for text in cleaned_newstop]

# %%
t0 = time()

lda_model_new = LdaModel(corpus=gen_corpus_new,
                       id2word=dictionary_new,
                       num_topics=10, 
                       random_state=5,
                       update_every=1,
                       chunksize=100,
                       passes=10,
                       alpha='auto',
                       per_word_topics=True)

print(time()-t0)
# Out:
# 334.08730840682983

# %%
# lda_model_new.save('data/model/lda.modelnew')
# lda_model_new = LdaModel.load('data/model/lda.modelnew')

# %%
lda_model_new.show_topics()
# Out:
# [(0,
#   '0.010*"citi" + 0.010*"water" + 0.010*"area" + 0.006*"year" + 0.005*"park" + 0.005*"nation" + 0.005*"air" + 0.005*"north" + 0.005*"plant" + 0.004*"south"'),
#  (1,
#   '0.024*"percent" + 0.022*"compani" + 0.013*"year" + 0.011*"market" + 0.010*"million" + 0.010*"billion" + 0.010*"busi" + 0.009*"bank" + 0.008*"price" + 0.007*"rate"'),
#  (2,
#   '0.017*"state" + 0.013*"unit" + 0.011*"countri" + 0.010*"govern" + 0.009*"war" + 0.008*"syria" + 0.008*"china" + 0.008*"forc" + 0.008*"presid" + 0.008*"russia"'),
#  (3,
#   '0.011*"peopl" + 0.008*"sai" + 0.007*"wai" + 0.006*"year" + 0.006*"women" + 0.004*"life" + 0.004*"need" + 0.004*"differ" + 0.004*"thing" + 0.003*"help"'),
#  (4,
#   '0.021*"polic" + 0.015*"offic" + 0.012*"kill" + 0.011*"peopl" + 0.010*"citi" + 0.009*"attack" + 0.008*"gun" + 0.008*"shoot" + 0.008*"told" + 0.007*"protest"'),
#  (5,
#   '0.008*"post" + 0.008*"twitter" + 0.007*"film" + 0.007*"olymp" + 0.006*"night" + 0.006*"movi" + 0.006*"video" + 0.006*"star" + 0.006*"stori" + 0.006*"perform"'),
#  (6,
#   '0.017*"state" + 0.011*"law" + 0.009*"plan" + 0.009*"court" + 0.009*"govern" + 0.009*"polici" + 0.008*"feder" + 0.008*"american" + 0.008*"tax" + 0.008*"administr"'),
#  (7,
#   '0.015*"report" + 0.012*"investig" + 0.010*"offici" + 0.009*"case" + 0.009*"depart" + 0.008*"email" + 0.008*"inform" + 0.007*"post" + 0.007*"attornei" + 0.007*"public"'),
#  (8,
#   '0.029*"student" + 0.023*"school" + 0.019*"game" + 0.015*"team" + 0.011*"colleg" + 0.010*"season" + 0.009*"plai" + 0.009*"player" + 0.009*"sport" + 0.008*"year"'),
#  (9,
#   '0.064*"trump" + 0.020*"clinton" + 0.016*"presid" + 0.014*"republican" + 0.013*"campaign" + 0.011*"elect" + 0.011*"democrat" + 0.010*"donald" + 0.010*"polit" + 0.009*"vote"')]

# %%
visnew = pyLDAvis.gensim.prepare(lda_model_new, gen_corpus_new, dictionary_new)

# %%
pyLDAvis.enable_notebook()
visnew

# %%
# Save to html
# pyLDAvis.save_html(visnew, 'ldanew.html')

# %% [markdown]
# ### Assigning topics based on keywords

# %%
def format_topics_sentences(ldamodel, corpus):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
#     contents = pd.Series(texts)
#     sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
for i in range(0, 10):
    print(lda_model_new.show_topic(i))
    print()
# Out:
# [('citi', 0.010200432), ('water', 0.009685914), ('area', 0.00952618), ('year', 0.005861368), ('park', 0.0054237465), ('nation', 0.004815536), ('air', 0.004758652), ('north', 0.0046952623), ('plant', 0.004673799), ('south', 0.0044658086)]
#
# [('percent', 0.023814801), ('compani', 0.021627992), ('year', 0.012897828), ('market', 0.010664429), ('million', 0.010331284), ('billion', 0.009840626), ('busi', 0.009542874), ('bank', 0.008880805), ('price', 0.0075456225), ('rate', 0.007393971)]
#
# [('state', 0.017151624), ('unit', 0.012591133), ('countri', 0.011211348), ('govern', 0.010462813), ('war', 0.008522371), ('syria', 0.008167333), ('china', 0.008159017), ('forc', 0.008079694), ('presid', 0.007967894), ('russia', 0.007942189)]
#
# [('peopl', 0.011263334), ('sai', 0.0077411523), ('wai', 0.007368372), ('year', 0.0060954383), ('women', 0.0059584347), ('life', 0.0037984333), ('need', 0.0036750655), ('differ', 0.00357594), ('thing', 0.0035441879), ('help', 0.0034585765)]
#
# [('polic', 0.021122452), ('offic', 0.015419299), ('kill', 0.011808004), ('peopl', 0.011015355), ('citi', 0.010379786), ('attack', 0.008629121), ('gun', 0.008382586), ('shoot', 0.007823942), ('told', 0.0075096805), ('protest', 0.007032426)]
#
# [('post', 0.008403099), ('twitter', 0.007565587), ('film', 0.0072924597), ('olymp', 0.0069922265), ('night', 0.006448911), ('movi', 0.0060242135), ('video', 0.0059154257), ('star', 0.0058533153), ('stori', 0.005825347), ('perform', 0.005715972)]
#
# [('state', 0.017374085), ('law', 0.011374776), ('plan', 0.009178355), ('court', 0.009172715), ('govern', 0.008682017), ('polici', 0.008545422), ('feder', 0.008451113), ('american', 0.007882377), ('tax', 0.00764816), ('administr', 0.007646937)]
#
# [('report', 0.015298568), ('investig', 0.011507157), ('offici', 0.009784265), ('case', 0.009299412), ('depart', 0.009051556), ('email', 0.00793431), ('inform', 0.007887639), ('post', 0.007464519), ('attornei', 0.006667343), ('public', 0.0066296333)]
#
# [('student', 0.029141407), ('school', 0.022857936), ('game', 0.01945006), ('team', 0.015482471), ('colleg', 0.01051615), ('season', 0.010489588), ('plai', 0.009101997), ('player', 0.008638293), ('sport', 0.00858279), ('year', 0.008232501)]
#
# [('trump', 0.063644834), ('clinton', 0.019702623), ('presid', 0.01555102), ('republican', 0.014032493), ('campaign', 0.013391972), ('elect', 0.010984299), ('democrat', 0.010599759), ('donald', 0.009827308), ('polit', 0.009574494), ('vote', 0.008853016)]

# %%
topic_nums = {
    0: 9,
    1: 7,
    2: 6,
    3: 1,
    4: 4,
    5: 8,
    6: 3,
    7: 5,
    8: 10,
    9: 2}

topic_map = {
    1: 'lifestyle-general',
    2: 'domestic-politics',
    3: 'government',
    4: 'police-shootings',
    5: 'fbi-investigation',
    6: 'foreign-politics',
    7: 'economy',
    8: 'arts-culture',
    9: 'zika-virus',
    10: 'college-sports'
}

# %% [markdown]
# ### Adding new column to articles dataframe - Dominant topic

# %%
t0 = time()

df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model_new, corpus=gen_corpus_new)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords']
df_dominant_topic.head(10)

print(time() - t0)
# Out:
# 135.80958199501038

# %%
df_dominant_topic['vis_num'] = df_dominant_topic['Dominant_Topic'].map(lambda x: topic_nums[x])

# %%
df_dominant_topic['topic'] = df_dominant_topic.vis_num.map(lambda x: topic_map[x])

# %%
df_dominant_topic[['vis_num', 'Topic_Perc_Contrib', 'topic']]
# Out:
#        vis_num  Topic_Perc_Contrib              topic
# 0            3              0.2552         government
# 1            1              0.7852  lifestyle-general
# 2            1              0.4822  lifestyle-general
# 3            2              0.4290  domestic-politics
# 4            1              0.4490  lifestyle-general
# ...        ...                 ...                ...
# 14252        3              0.3861         government
# 14253        2              0.4822  domestic-politics
# 14254        9              0.6373         zika-virus
# 14255        1              0.2394  lifestyle-general
# 14256        2              0.4461  domestic-politics
#
# [14257 rows x 3 columns]

# %%
df_sample_inds = df_sample1.reset_index()
df_sample_inds = df_sample_inds.drop(['index'], axis=1)

# %%
df_sample_inds
# Out:
#            id                                              title  \
# 0       17293  Weak Federal Powers Could Limit Trump’s Climat...
# 1       17318  Tips for Your Post-Holiday Clutter Purge - The...
# 2       17321  France Lets Workers Turn Off, Tune Out and Liv...
# 3       17352  In Republicans’ Ethics Office Gambit, a Specta...
# 4       17361  How We Put Together Our 52 Places to Go List -...
# ...       ...                                                ...
# 14252  218016  With new monuments in Nevada, Utah, Obama adds...
# 14253  218017  Memo to Trump: There can be only one president...
# 14254  218052  Rare coast-to-coast cold snap to engulf Lower ...
# 14255  218055  A CIA calendar the CIA gift shop refuses to se...
# 14256  218069  On Russia, Trump is incapable of looking past ...
#
#            publication            author        date    year  month  \
# 0       New York Times     Justin Gillis  2017-01-03  2017.0    1.0
# 1       New York Times  Michelle Higgins  2017-04-11  2017.0    4.0
# 2       New York Times   Alissa J. Rubin  2017-01-03  2017.0    1.0
# 3       New York Times        Carl Hulse  2017-01-05  2017.0    1.0
# 4       New York Times               NaN  2017-01-15  2017.0    1.0
# ...                ...               ...         ...     ...    ...
# 14252  Washington Post   Juliet Eilperin  2016-12-28  2016.0   12.0
# 14253  Washington Post       Ruth Marcus  2016-12-28  2016.0   12.0
# 14254  Washington Post     Jason Samenow  2016-12-29  2016.0   12.0
# 14255  Washington Post       Ian Shapira  2016-12-29  2016.0   12.0
# 14256  Washington Post       Ruth Marcus  2016-12-30  2016.0   12.0
#
#                                                      url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14252  https://web.archive.org/web/20161229004018/htt...
# 14253  https://web.archive.org/web/20161229004018/htt...
# 14254  https://web.archive.org/web/20161230000842/htt...
# 14255  https://web.archive.org/web/20161230000842/htt...
# 14256  https://web.archive.org/web/20161231004909/htt...
#
#                                                  content      leaning factual
# 0      With Donald J. Trump about to take control of ...  Left-Center    High
# 1      With the year winding down and New Year’s reso...  Left-Center    High
# 2      PARIS  —   If the world does not envy the Fren...  Left-Center    High
# 3      WASHINGTON  —   Majorities in Congress often o...  Left-Center    High
# 4      For the 12th straight year, the Travel section...  Left-Center    High
# ...                                                  ...          ...     ...
# 14252        President Obama on Wednesday created new...  Left-Center    High
# 14253   One of the hallmarks of our democratic system...  Left-Center    High
# 14254       Frigid air will grip an unusually large p...  Left-Center    High
# 14255     Far Side cartoons, Ansel Adams landscapes, ...  Left-Center    High
# 14256         Donald Trump, having dismissed as “ridi...  Left-Center    High
#
# [14257 rows x 11 columns]

# %%
df_gentops = pd.concat([df_sample_inds, df_dominant_topic[['vis_num', 'Topic_Perc_Contrib', 'topic']]], axis=1)

# %%
df_gentops
# Out:
#            id                                              title  \
# 0       17293  Weak Federal Powers Could Limit Trump’s Climat...
# 1       17318  Tips for Your Post-Holiday Clutter Purge - The...
# 2       17321  France Lets Workers Turn Off, Tune Out and Liv...
# 3       17352  In Republicans’ Ethics Office Gambit, a Specta...
# 4       17361  How We Put Together Our 52 Places to Go List -...
# ...       ...                                                ...
# 14252  218016  With new monuments in Nevada, Utah, Obama adds...
# 14253  218017  Memo to Trump: There can be only one president...
# 14254  218052  Rare coast-to-coast cold snap to engulf Lower ...
# 14255  218055  A CIA calendar the CIA gift shop refuses to se...
# 14256  218069  On Russia, Trump is incapable of looking past ...
#
#            publication            author        date    year  month  \
# 0       New York Times     Justin Gillis  2017-01-03  2017.0    1.0
# 1       New York Times  Michelle Higgins  2017-04-11  2017.0    4.0
# 2       New York Times   Alissa J. Rubin  2017-01-03  2017.0    1.0
# 3       New York Times        Carl Hulse  2017-01-05  2017.0    1.0
# 4       New York Times               NaN  2017-01-15  2017.0    1.0
# ...                ...               ...         ...     ...    ...
# 14252  Washington Post   Juliet Eilperin  2016-12-28  2016.0   12.0
# 14253  Washington Post       Ruth Marcus  2016-12-28  2016.0   12.0
# 14254  Washington Post     Jason Samenow  2016-12-29  2016.0   12.0
# 14255  Washington Post       Ian Shapira  2016-12-29  2016.0   12.0
# 14256  Washington Post       Ruth Marcus  2016-12-30  2016.0   12.0
#
#                                                      url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14252  https://web.archive.org/web/20161229004018/htt...
# 14253  https://web.archive.org/web/20161229004018/htt...
# 14254  https://web.archive.org/web/20161230000842/htt...
# 14255  https://web.archive.org/web/20161230000842/htt...
# 14256  https://web.archive.org/web/20161231004909/htt...
#
#                                                  content      leaning factual  \
# 0      With Donald J. Trump about to take control of ...  Left-Center    High
# 1      With the year winding down and New Year’s reso...  Left-Center    High
# 2      PARIS  —   If the world does not envy the Fren...  Left-Center    High
# 3      WASHINGTON  —   Majorities in Congress often o...  Left-Center    High
# 4      For the 12th straight year, the Travel section...  Left-Center    High
# ...                                                  ...          ...     ...
# 14252        President Obama on Wednesday created new...  Left-Center    High
# 14253   One of the hallmarks of our democratic system...  Left-Center    High
# 14254       Frigid air will grip an unusually large p...  Left-Center    High
# 14255     Far Side cartoons, Ansel Adams landscapes, ...  Left-Center    High
# 14256         Donald Trump, having dismissed as “ridi...  Left-Center    High
#
#        vis_num  Topic_Perc_Contrib              topic
# 0            3              0.2552         government
# 1            1              0.7852  lifestyle-general
# 2            1              0.4822  lifestyle-general
# 3            2              0.4290  domestic-politics
# 4            1              0.4490  lifestyle-general
# ...        ...                 ...                ...
# 14252        3              0.3861         government
# 14253        2              0.4822  domestic-politics
# 14254        9              0.6373         zika-virus
# 14255        1              0.2394  lifestyle-general
# 14256        2              0.4461  domestic-politics
#
# [14257 rows x 14 columns]

# %%
grouped = df_gentops.groupby(['leaning', 'topic']).topic.count()
grouped
# Out:
# leaning        topic
# Least Biased   arts-culture           15
#                college-sports          8
#                domestic-politics     101
#                economy               425
#                fbi-investigation      97
#                foreign-politics      211
#                government             98
#                lifestyle-general      18
#                police-shootings       72
#                zika-virus             26
# Left           arts-culture           92
#                college-sports         34
#                domestic-politics     558
#                economy                31
#                fbi-investigation     213
#                foreign-politics      187
#                government            234
#                lifestyle-general     466
#                police-shootings      234
#                zika-virus            116
# Left-Center    arts-culture          192
#                college-sports        153
#                domestic-politics     972
#                economy               409
#                fbi-investigation     441
#                foreign-politics      458
#                government            507
#                lifestyle-general    1981
#                police-shootings      473
#                zika-virus            252
# Right          arts-culture           18
#                college-sports          9
#                domestic-politics     327
#                economy                13
#                fbi-investigation      61
#                foreign-politics       88
#                government            121
#                lifestyle-general     276
#                police-shootings      117
#                zika-virus             26
# Right-Center   arts-culture          127
#                college-sports        174
#                domestic-politics     137
#                economy               212
#                fbi-investigation     130
#                foreign-politics       36
#                government             46
#                lifestyle-general     574
#                police-shootings      234
#                zika-virus             79
# Right-Extreme  arts-culture          121
#                college-sports         40
#                domestic-politics     883
#                economy                77
#                fbi-investigation     172
#                foreign-politics      196
#                government            175
#                lifestyle-general     332
#                police-shootings      352
#                zika-virus             30
# Name: topic, dtype: int64

# %%
for lean in df_gentops.leaning.unique():
    print(lean)
    print(grouped[lean].sort_values(ascending = False).head(3)/grouped[lean].sum() * 100)
    print()
# Out:
# Left-Center
# topic
# lifestyle-general    33.932854
# domestic-politics    16.649538
# government            8.684481
# Name: topic, dtype: float64
#
# Right-Extreme
# topic
# domestic-politics    37.132044
# police-shootings     14.802355
# lifestyle-general    13.961312
# Name: topic, dtype: float64
#
# Left
# topic
# domestic-politics    25.773672
# lifestyle-general    21.524249
# police-shootings     10.808314
# Name: topic, dtype: float64
#
# Right
# topic
# domestic-politics    30.965909
# lifestyle-general    26.136364
# government           11.458333
# Name: topic, dtype: float64
#
# Right-Center
# topic
# lifestyle-general    32.818754
# police-shootings     13.379074
# economy              12.121212
# Name: topic, dtype: float64
#
# Least Biased
# topic
# economy              39.682540
# foreign-politics     19.701214
# domestic-politics     9.430439
# Name: topic, dtype: float64
